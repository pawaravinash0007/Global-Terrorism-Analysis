# %% [markdown]
# <a href="https://colab.research.google.com/github/pawaravinash0007/Global-Terrorism-Analysis/blob/Global-Terrorism-Analisys/Global_Terrorism_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Global Terrorism Impact
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Avinash Pawar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Here we have dataset of demotic and international terrorist attacks more than 180000 attacks during the years 190 to 2017.This dataset is available from START Headquater University of Maylend. This projects will give details of terroris activaties in the world as well as top most countries.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/pawaravinash0007/Global-Terrorism-Analysis.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Terrorists destroy Infrastructure, human health, economic resources. Impact of terrorism directly affects the growth of industry as well as human being. Find the motive of attacks and overcome it by analysed data given**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# * The duration of an incident extended less than 24 hours and more than 24 hours.
# * Find wether attack is international or domestic
# * Find wether attack motove is money or not for money
# 1.  Find the most number of attacks, casualties, Killed, Wounded year wise
# 2.	Find the Least number of attacks, casualties, Killed, Wounded year wise
# 3.	Find the most number of attacks, casualties, Killed, Wounded country wise
# 4.	Find the Least number of attacks, casualties, Killed, Wounded country wise
# 5.	Find the most number of attacks, casualties, Killed, Wounded city wise
# 6.	Find the most number of attacks, casualties, Killed, Wounded Terrorist Group wise attack
# 7.	Find the Least number of attacks, casualties, Killed, Wounded Terrorist Group wise attack
# 8.	Find the most number of attacks, casualties, Killed, Wounded attack type wise attacks
# 9.	Find the Least number of attacks, casualties, Killed, Wounded attack type wise attacks
# 10.	Find the most number of attacks, casualties, Killed, Wounded attack target type wise attacks
# 11.	Find the Least number of attacks, casualties, Killed, Wounded attack target type wise attacks
# 12.	Find the most number of attacks, casualties, Killed, Wounded group and country wise attack
# 13.	Find the Least number of attacks, casualties, Killed, Wounded group and country wise attack
# 14.	Total number of Causalities due to terrorist attacks from 1970 to 2017 across the world
# 15.	Total number of people killed due to terrorist attacks from 1970 to 2017 across the world

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np 
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from numpy import math
from numpy import loadtxt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Dataset First View

# %%
#Error Resolution: UnicodeDecodeError: 'utf-8'codec cant be decode so chang enconding to ISO-8859-1
data_path="/content/drive/MyDrive/Global Terrorisum /Global Terrorism Data.csv"
dataset=pd.read_csv(data_path,encoding="ISO-8859-1")

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset First Look dataset.head(number of rows) default rows are 5 
dataset.head(3)

# %% [markdown]
# ### Dataset Information

# %%
# In given dataset total Rows = 181691 and Columns = 135
dataset.shape

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(dataset[dataset.duplicated()])

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(dataset.isnull().sum())

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Given dataset values are unique and contains the missing values

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
for i in list(dataset.columns):
  print(i,end=",")

# %%
list(dataset.columns)

# %%
# Dataset Describe
dataset.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ![variables.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in dataset.columns.tolist():
  print("No. of unique values in ",i,"is",dataset[i].nunique(),".")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Create a copy of the current dataset and assigning to df
my_data=dataset.copy()
my_data.head(3)

# %%
list(my_data.columns)

# %%
my_data.columns

# %%
my_data.head(3)

# %%
selected_data=my_data[["eventid","extended","iyear","imonth","iday","country_txt","region_txt","provstate","city","success","nreleased","hostkidoutcome_txt","ransom","summary","attacktype1_txt","targtype1_txt","gname","motive","weaptype1_txt","nkill","nwound","addnotes","INT_LOG"]]

# %%
selected_data.rename(columns={"eventid":"Event_ID","extended":"Duration_of_Event","iyear":"Year",
                        "imonth":"Month","iday":"Day","country_txt":"Country_name","region_txt":"Region_Name",
                        "provstate":"State","city":"city","success":"Attack_Success","nreleased":"No_of_Hostage_release",
                        "hostkidoutcome_txt":"Hostage_Details","ransom":"Money_Demanded",
                        "summary":"Incident_Summary","attacktype1_txt":"Type_of_Attack","targtype1_txt":"Target_Location",
                        "gname":"Perpetrator_Group_Name","motive":"Motive","weaptype1_txt":"Weapon_Type","nkill":"Total_Killed",
                        "nwound":"Total_Injured","addnotes":"Additional_Notes","INT_LOG":"International_Logistical"},inplace=True)

# %%
selected_data.head(3)

# %%
selected_data["Total_Killed"]=selected_data["Total_Killed"].fillna(0)
selected_data["Total_Injured"]=selected_data["Total_Injured"].fillna(0)
selected_data["Casualty"]= selected_data["Total_Killed"]  + selected_data["Total_Injured"]

# %%
selected_data.columns

# %%
selected_data.describe()

# %% [markdown]
# ###Total attacks information
# 1.   Total People killed during atack : 1570
# 2.   Total Number of lnjured people during attack : 8191
# 3.   Total Peoples casulity during attack : 9574
# 3. Total number of hostages release : 2769

# %%
# Long Attack The duration of an incident extended more than 24 hours. 
# -99 means unknown hostage release number
long_attack=selected_data[selected_data['Duration_of_Event']==1]
long_attack.head(3)

# %%
long_attack.info()

# %%
long_attack.shape

# %%
long_attack.isnull().sum()

# %%
long_attack["Total_Killed"]=long_attack["Total_Killed"].fillna(0)
long_attack["Total_Injured"]=long_attack["Total_Injured"].fillna(0)
long_attack["Casualty"]= long_attack["Total_Killed"]  + long_attack["Total_Injured"]

# %%
long_attack.describe()

# %% [markdown]
# ### Long attacks information
# 1.   People killed in Long attack(more than 24 hours) : 1570
# 2.   People lnjured in long attack(more than 24 hours) : 1001
# 3.   Peoples casulity during long attack : 1570
# 3.   Total number of hostages release during long attack : 2769

# %%
# short Attack The duration of an incident extended more than 24 hours. 
# -99 means unknown hostage release number
short_attack=selected_data[selected_data['Duration_of_Event']==0]
short_attack.head(3)

# %%
short_attack.info()

# %%
short_attack.shape

# %%
short_attack.isnull().sum()

# %%
short_attack.describe()

# %% [markdown]
# ### Short attacks information
# 1.   People killed in Short attack(less than 24 hours) : 1384
# 2.   People lnjured in Short attack(less than 24 hours) : 8191
# 3.   Peoples casulity during Short attack : 9574
# 3.   Total number of hostages release during Short attack : 1201

# %%
# Long attack for Money
long_attack_for_money=selected_data[selected_data['Money_Demanded']==1]
long_attack_for_money['Money_Demanded']

# %%
# attack for money  
long_attack_motive_money=long_attack_for_money[["Country_name","Money_Demanded","Year"]]
long_attack_motive_money.head()

# %%
# Long attack motive not for money
long_attack_for_money.describe()

# %% [markdown]
# ### Long attack motive is money
# 1.   Total number of Long attack due to money is : 1299

# %%
# lONG ATTACK NOT FOR MONEY
long_attack_notfor_money=selected_data[selected_data['Money_Demanded']==0]
long_attack_notfor_money['Money_Demanded']

# %%
long_attack_motive_notfor_money=long_attack_notfor_money[["Country_name","Money_Demanded","Year"]]
long_attack_motive_notfor_money.head()

# %%
# Long attack motive for money
long_attack_notfor_money.describe()

# %% [markdown]
# ### Long attack motive is money
# 1.   Total number of Long attack not for  money is : 74684

# %%
# Attack by internation group
international_group_attack=selected_data[selected_data['International_Logistical']==1]
international_group_attack.describe()

# %% [markdown]
# ### Internatioinal Group attack
# 1. Total 7188 internation group attack are counted

# %%
# Attack by demostic group
demoestic_group_attack=selected_data[selected_data['International_Logistical']==0]
demoestic_group_attack.describe()

# %% [markdown]
# ### Demostic Group attack
# 1. Total 81976 internation group attack are counted

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ###Total attacks information
# 1.   Total People killed during atack : 1570
# 2.   Total Number of lnjured people during attack : 8191
# 3.   Total Peoples casulity during attack : 9574
# 3. Total number of hostages release : 2769
#
# ### Long attacks information
# 1.   People killed in Long attack(more than 24 hours) : 1570
# 2.   People lnjured in long attack(more than 24 hours) : 1001
# 3.   Peoples casulity during long attack : 1570
# 3.   Total number of hostages release during long attack : 2769
#
# ### Short attacks information
# 1.   People killed in Short attack(less than 24 hours) : 1384
# 2.   People lnjured in Short attack(less than 24 hours) : 8191
# 3.   Peoples casulity during Short attack : 9574
# 3.   Total number of hostages release during Short attack : 1201
#
# ### Long attack motive is money
# 1.   Total number of Long attack due to money is : 1299
#
# ### Long attack motive is not for money
# 1.   Total number of Long attack not for money is : 74684

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Various attack Types

# %%
selected_data.columns

# %%
# Chart - 1 Type of attacks : TOA 
TOA=selected_data["Type_of_Attack"].value_counts()
dict(TOA)

# %%
TOA.plot(kind='bar',
         figsize=(20,15),
         color=['b','r','g'],
         fontsize=15)
plt.title("Types of Attacks of over the world",fontsize=15)
plt.xlabel("Attacking Method",fontsize=15)
plt.ylabel("Total Attack Counts",fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We are working on single variable of data as multiple attacking methods. Barch chart X axis contain allacking methods and Y axis contain the total number of Attack happens. Which gives the representation of data with rectangular bars.

# %% [markdown]
# 2 What is/are the insight(s) found from the chart?

# %% [markdown]
# Inside the bar chart we found that the Bombing / Expolosion attacking method is widely used for the attack where as hijacking is realry used for the attack this shows that terrorist are most foucs on the killing of peoples and distroy the infracturecte.

# %% [markdown]
# 3 Will the gained insights help creating a positive business impact?

# %% [markdown]
# We know that terrorist are mostly like Bombing. So we can monitor the agency and organization who provide the bombing materials and places where bombing happens we will deploy anti bombing equipment who detect the bombing material also keep in mind the other attack  will provide training to local police to face real time situtation of attacks like army.

# %% [markdown]
# ### Chart - 2 : Weapon Types used for attack

# %%
WT=selected_data["Weapon_Type"].value_counts()
WT

# %%
WT.plot(kind='bar',
         figsize=(20,15),
         color=['b','r','g'],
         fontsize=15)
plt.title("Types of WEAPON usd for attack all over the world",fontsize=15)
plt.xlabel("Weapon names",fontsize=15)
plt.ylabel("Total Attack Counts",fontsize=15)
plt.show()

# %% [markdown]
# ### **1 Why did you pick the specific chart?**

# %% [markdown]
# Here in this chart we displaying only single variable of so bar and line chart we can use here bar chart display information easy to understand.

# %% [markdown]
# ## 2 What is/are the insight(s) found from the chart?

# %% [markdown]
# We observe that explosives and firearms  are most widely used weapon during attack and similier to incendiary , chemical weapons are may be used by terrorist organization. Chemical and Biological weapons  least used for the attacks.

# %% [markdown]
# ## 3 Will the gained insights help creating a positive business impact?

# %% [markdown]
# possiblities of attacks weapons we know then we can develop and create suitable equipment which protect our losses and protect our infracture and man power. We can provide the training to our security guards to identify and the third party person who trying to attack

# %% [markdown]
# ### Chart 3 : Duration of attacks Long attacks and Short Attack

# %%
LT=selected_data["Duration_of_Event"].value_counts()
LT.value_counts().plot(kind="pie",
                       figsize=(15,6),
                       autopct="%1.1f%%",
                       startangle=60,
                       labels=["long Attack(%)","Short_attack(%)"])

# %% [markdown]
# 1 Why did you pick the specific chart?

# %% [markdown]
# To display single variable data we are using Pie chart which is easy to understand and gives the information in percentage of short and long attacks

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?

# %% [markdown]
# We found the more than 24 hours attacks are 50% and short attack are also 50%

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?

# %% [markdown]
# 1. CCTV is uitilize for the tracking of attacks.
# 2. While manufacturing the explosive we can give them unique identification number
# 3. Primary souce of data helpful for the identify the person and his activities.
# 4. Short attack are completed in one day and for long attack more than one day is required. So we can understand that our short attack and long attack motive. if someone attaking for money then they may not be a terrorist so our political leadrs and officer will try to communicate and run the operation as per the communication.

# %% [markdown]
# #### Chart - 4 Various attacking group international group or Demotic group

# %%
selected_data.columns

# %%
IG=selected_data["International_Logistical"].value_counts()
IG

# %% [markdown]
# ### Details of variables
# * 1 menas : International group attack
# * 0 Means : Demostic group attack
# * -9 means : Attack from unknown gruop

# %%
IG=selected_data["International_Logistical"].value_counts()
IG.value_counts().plot(kind="pie",
                       figsize=(15,6),
                       autopct="%1.1f%%",
                       startangle=60,
                       labels=["International Group","Demostic Group ","Unknown Group"])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Single variable data we can easily observer in percentage. Basically their are three groups so pie chart gives the informatioin properly and easy to understand

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Anyone can understand internation group , domestic group and Unknown group percentage of attacks

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# 1. International Group: We can track the activites of Broder area in each region whiere international peoples can easilty entered. Passport is mandetory for tracking activites. Centeral Forces will handel international groups. Create a database for all kind of peoples for future tracking
#
# 2. Demostic Group : State / Local Police tracks the activites. Police will do investigation as per their sources. Due to lack of real time information polices are unable to predict situtation. So we can improve teachnology for Communication and other sectores.
# 3. Unknown Group: We will find the area where the lack of basic resources and peoples will do criminal activites for their daily needs. Identify such peoples and provide them kind of job so that they will live happly
#
# 4. As per attacks we can deploy our officer and solidgers on the location if attack is demostic then local police will helps the specilist officer and find the black ship before the attack. During the international attacks we have to deal with the different polices of attacks. for for new unknown groups our officers can develop different opeartion which take impact on operations cost and beneits.

# %% [markdown]
# #### Chart - 5 Motive of attack is money / not for money:

# %%
selected_data.columns

# %%
MA=selected_data["Money_Demanded"].value_counts()
MA

# %% [markdown]
# # understand variables
# * 1 means money demanded
# * 0 means money not demanded
# * -9 means unknown

# %%
MA.plot(kind="pie",
        figsize=(15,6),
        autopct="%1.1f%%",
        startangle=60,
        labels=["money demanded","money not demanded","Unknown motive"])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart shows the details of motive in the percentage form which we can understand in first view

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Mostly attacks are happen because of money. its percentage is 96.5 % and only 1.7% motiev is uknown and 1.8% motive is not for money. To fiind attack motive this graph is useful

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. Motive for money : People suffering form basic needs they can involve such terriorist  activity for their growth. So we can identify their needs and  as per the demand of the peoples develope the resourse.
#
# 2. Not for Money : Peoples having motive to killed and damanage infrastructure. We can indetify them with help of technology like face detection , Biometric Identification. Finally we will create a database of various records and find out the black ship entered
#
# 3. Unknown Motive : Due to some specific activity like cast , festival , religion.Identify the target peoples and resolve their questions so that they will avoid to do terrorist attack
#
#
# Motive is very important for attack once officers understand the motive of attack then they can start enquiry as per the motive. If attack is for money then we will develope the resources in the perticular area and convert the terrorist in to skilled peoples. If attack motive is killing peoples then we can our officer will prepare the special operation and find the main leader who create negative energy.

# %% [markdown]
# ## Chart-6 Year Wise Analysis of ATTACKS , CASUALITY , KILLED and INJURED Peoples

# %% [markdown]
# ##  **Attacks**

# %%
selected_data.columns

# %%
# Chart - 5 Find the number of attacks year wise 
YA=selected_data["Year"].value_counts()
YA

# %%
# sort year from 1970 to 2017
YA.sort_index()

# %%
# create a frame of data 
YA1=YA.sort_index().to_frame().reset_index().rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")
YA1.head()

# %%
YA1.plot(kind="bar",
         figsize=(20,14),
         fontsize=15,
         color=['g'],)
plt.title("From 1970 to 2017 Year wise attack details")
plt.xlabel("Year of Attack",fontsize=15)
plt.ylabel("Number of attacks ",fontsize=15)
plt.show()

# %% [markdown]
# ## **Causalities Peoples**

# %%
# Chart - 6 casuality 
CY=selected_data[["Casualty","Year"]].groupby("Year").sum()
CY.head(5)

# %%
CY.plot(kind="bar",
        figsize=(20,14),
        fontsize=15)
plt.title("From 1970 to 2017 year wise number of casualites",fontsize=15)
plt.xlabel("Years from 1970 to 2017",fontsize=15)
plt.ylabel("Number of Casualties",fontsize=15)
plt.show()

# %% [markdown]
# ## **Killed People**

# %%
# Chart - 7 visualization code
KY=selected_data[["Year","Total_Killed"]].groupby("Year").sum()
KY.head()

# %%
KY.plot(kind="bar",
        figsize=(20,15),
        color=['r'],
        fontsize=15)
plt.title("From year 1970 to 2017 Total killed peoples",fontsize=15)
plt.xlabel("Years from 1970 to 2017",fontsize=15)
plt.ylabel("Number of  killed Peoples",fontsize=15)
plt.show()

# %% [markdown]
# ## **Injured  Peoples**

# %%
# Chart - 8 visualization code
WP=selected_data[["Year","Total_Injured"]].groupby("Year").sum()
WP.head()

# %%
WP.plot(kind="bar",
        figsize=(20,15),
        color=['y'],
        fontsize=15)
plt.title("From year 1970 to 2017 total number of people injured",fontsize=15)
plt.xlabel("Years from 1970 to 2017",fontsize=15)
plt.ylabel("Number of Injured Peoples",fontsize=15)
plt.show()

# %% [markdown]
# ## 1. Why did you pick the specific chart?

# %% [markdown]
# We are working on only one variable that is year so bar chart is very good representation of data and easy to understand

# %% [markdown]
# ## 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   Aattacks
# * In the year **2014 maximum terrorist attacks** are observed
# * In year year **1973 mininmum terrorist attacks** are observed
# * From **2004 to 2014 frequency of terrorist attacks are increased**
# * After **2014 to 2017** We **control the terrorist activiies**
# 2.   Causalities Peoples
# * In the year **2014 maximum terrorist Causalities** are observed
# * In year year **1971 mininmum terrorist Causalities** are observed
# * From **2011 to 2014 frequency of terrorist Causalities are increased**
# * After **2014 to 2017** We **control the Causalities during attacks**
# 3. Killed People
# * In the year **2014 maximum Peoples are killed** during terrorist attacks
# * In year year **1970 mininmum Peoples are killed **during terrorist attacks
# * From **2010 to 2014 frequency of killed people are increased**
# * After **2014 to 2017** We **control the Peoples killing **during terrorist attacks
# 4. Injured Peoples
# * In the year **2015 maximum Injured peoples** during attack are observed
# * In year year **1973 mininmum Injured peoples** during attack are observed
# * From **2012 to 2015 frequency of Injured peoples** during attack are increased
# * After 2015 to 2017 frequency of Injured peoples during attack are decreases

# %% [markdown]
# ## 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# ## **1. In the Terrorist country:**
# Our trained RAW Spy agent collect the necessary information and share it with the secured network to prevent the attacks which helps us to prevent  damage of infrastructure, human health and dcrease the load on Health agencies
# ## **2. On the Broder:**
# Create a data based of every peoples who crossed the broder and analysis their data after every 6 months or 1 year so that we can track the broder activities. Mandateory documents is Passport we can insert the tracking chip inside the passport to find the peoples and their ativities
# ## **3 In Target Country:**
# When the terrorist plan for attacks that time they are reach the target country and in contact with the local peoples they will execute the activities. So  rent home, hotels , gest houses will be monitor with help of CCTV and Create a primary source of data base of every entry. To indentify the terrorist and Helping persons
# ## **4 Hospital Services:**
# After attacks we can aobserve lots of load on the primary health care. So we can Register every peoples on Online Registration system and while provideding them services with help of unique id we can track their hospital records so that we will provides them best tretement and best doctors and it helps us to indeify the balck ship peoples.
# here is link for ORS Hospitals https://ors.gov.in/orsportal

# %% [markdown]
# ## **Chart-7  Region Wise Analysis of ATTACKS, CASUALITY, KILLED and INJURED Peoples**

# %% [markdown]
# ## **Attack**

# %%
selected_data.columns

# %%
RW=pd.crosstab(selected_data.Year,selected_data.Region_Name)
RW.head()

# %%
RW.plot(kind="area",
        stacked=False,
        alpha=0.5,
        figsize=(20,10))
plt.title("Various Location wise  attack",fontsize=15)
plt.xlabel("Year From 1970 to 2017",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# ## **Attack**

# %%
selected_data.columns

# %%
# Chart - 10 visualization code
AR=selected_data[["Region_Name","Year"]].groupby("Region_Name").sum()
AR

# %%
AR.plot(kind="bar",
        figsize=(20,15),
        color=['g'],
        fontsize=15)
plt.title("From Year 1970 to 2017 Total region wise attacks",fontsize=15)
plt.xlabel("Region Name",fontsize=15)
plt.ylabel("Number of attack ",fontsize=15)
plt.show()

# %% [markdown]
# ## **Causalities Peoples**

# %%
# Chart - 11 visualization code
CR=selected_data[["Region_Name","Casualty"]].groupby("Region_Name").sum()
CR

# %%
CR.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("From year 1970 to 2017 total region wise Casuality",fontsize=15)
plt.xlabel("Region Name",fontsize=15)
plt.ylabel("Number of Casuality ",fontsize=15)
plt.show()

# %% [markdown]
# ## **Killed Peoples**

# %%
# Chart - 12 visualization code
RK=selected_data[["Region_Name","Total_Killed"]].groupby("Region_Name").sum()
RK

# %%
RK.plot(kind="bar",
        figsize=(20,15),
        color=['r'],
        fontsize=15)
plt.title("From year 1970 to 2017 total region wise Killed peoples",fontsize=15)
plt.xlabel("Region Name",fontsize=15)
plt.ylabel("Number of  killed Peoples",fontsize=15)
plt.show()

# %% [markdown]
# ## **Injured Peoples**

# %%
# Chart - 13 visualization code
RWP=selected_data[["Region_Name","Total_Injured"]].groupby("Region_Name").sum()
RWP

# %%
RWP.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("From Year 1970 to 2017 region wise total  injured peoples",fontsize=15)
plt.xlabel("Region Name",fontsize=15)
plt.ylabel("Number of injured peoples",fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we used area and bar chart to display the information properly with single variables data. Beause of the grphs we can easily understand and find the noumer of affected peoples

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   Aattacks
# * In the region **Middle East & North Africa** *maximum number* of t**errorist    Aattacks** are observed
# * In the region **Australasia & Oceania** *minmum number* of t**errorist    Aattacks** are observed
#
# 2.   Causalities Peoples
# * In the region **Middle East & North Africa** *maximum number* of **Causalities Peoples** are observed
# * In the region **Australasia & Oceania**  minmum number* of **causalities Peoples** are observed
# 3. Killed People
# * In the region **Middle East & North Africa** *maximum number* of **peoples killed** due to terrorist    Aattacks are observed
# * In the region **Australasia & Oceania** *minmum number* of **peoples killed** due to terrorist    Aattacks are observed
# 4. Injured Peoples
# * In the region **Middle East & North Africa** *maximum number* of **peoples Injured** due to terrorist    Aattacks are observed
# * In the region **Australasia & Oceania** *minmum number* of **peoples Injured** due to terrorist    Aattacks are observed

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## **1. In the Terrorist country:**
# Our trained RAW Spy agent collect the necessary information and share it with the secured network to prevent the attacks which helps us to prevent  damage of infrastructure, human health and dcrease the load on Health agencies
# ## **2. On the Broder:**
# Create a data based of every peoples who crossed the broder and analysis their data after every 6 months or 1 year so that we can track the broder activities. Mandateory documents is Passport we can insert the tracking chip inside the passport to find the peoples and their ativities
# ## **3 In Target Country:**
# When the terrorist plan for attacks that time they are reach the target country and in contact with the local peoples they will execute the activities. So  rent home, hotels , gest houses will be monitor with help of CCTV and Create a primary source of data base of every entry. To indentify the terrorist and Helping persons
# ## **4 Hospital Services:**
# After attacks we can aobserve lots of load on the primary health care. So we can Register every peoples on Online Registration system and while provideding them services with help of unique id we can track their hospital records so that we will provides them best tretement and best doctors and it helps us to indeify the balck ship peoples.

# %% [markdown]
# ## **Chart - 8  Top 10 Country wise ATTACKS, CASUALITY, KILLED and INJURED Peoples**

# %% [markdown]
# ## **Top 10 Attack**

# %%
selected_data.columns

# %%
CWA=selected_data["Country_name"].value_counts().head(10)
CWA

# %%
CWA.plot(kind="bar",
        figsize=(20,15),
         color=['g'],
        fontsize=15)
plt.title(" From year 1970 to 2017 TOP 10 Country wise attacks",fontsize=15)
plt.xlabel("Country Name",fontsize=15)
plt.ylabel("Number of attacks",fontsize=15)
plt.show()

# %% [markdown]
# ## **Top 10 Country**

# %%
selected_data.columns

# %%
CWC=selected_data[["Country_name","Casualty"]].groupby("Country_name").sum().sort_values(by="Casualty",ascending=False).head(10)

# %%
CWC.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("From year 1970 to 2017 TOP 10 Country wise Casuality",fontsize=15)
plt.xlabel("Country Name",fontsize=15)
plt.ylabel("Number of Casuality",fontsize=15)
plt.show()

# %% [markdown]
# ## **Top 10 Killed Peoples**

# %%
CWk=selected_data[["Country_name","Total_Killed"]].groupby("Country_name").sum().sort_values(by="Total_Killed",ascending=False).head(10)
CWk

# %%
CWk.plot(kind="bar",
        figsize=(20,15),
         color=['r'],
        fontsize=15)
plt.title("From year 1970 to 2017 TOP 10 Country wise Total Killed Peoples",fontsize=15)
plt.xlabel("Country Name",fontsize=15)
plt.ylabel("Number of Killed Peoples",fontsize=15)
plt.show()

# %% [markdown]
# ## **Injured peoples**

# %%
CWW=selected_data[["Country_name","Total_Injured"]].groupby("Country_name").sum().sort_values(by="Total_Injured",ascending=False).head(10)
CWW

# %%
CWW.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("From year 1970 to 2017 TOP 10 Country wise Total Injured Peoples",fontsize=15)
plt.xlabel("Country Name",fontsize=15)
plt.ylabel("Number of Injured Peoples",fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart easily uderstand for single variable of data it is most preferable

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   Aattacks
# * In the city **Iraq** *maximum number* of t**errorist    Aattacks** are observed
# * In the city **Turkey** *minmum number* of t**errorist    Aattacks** are observed
#
# 2.   Causalities Peoples
# * In the city **Iraq** *maximum number* of **Causalities Peoples** are observed
# * In the city **Philippines**  minmum number* of **causalities Peoples** are observed
# 3. Killed People
# * In the city **Iraq** *maximum number* of **peoples killed** due to terrorist    Aattacks are observed
# * In the city **El Salvador** *minmum number* of **peoples killed** due to terrorist    Aattacks are observed
# 4. Injured Peoples
# * In the city **Iraq** *maximum number* of **peoples Injured** due to terrorist    Aattacks are observed
# * In the city **Colombia** *minmum number* of **peoples Injured** due to terrorist    Aattacks are observed

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## **1. City Impact:**
# Monitor the population of city and important infrastructure of city where possibilities of Terrorist attacks are more and Implement latest technology like IoT Based CCTV Cameras , Secure Biomatirc and metal detectore are utilize for the entry and exit points of VIP and Important area of city like Government offers, Schools , Coleges and Various croudy areas
# ## **2. Hospital Impact:**
# Hostipal facility are clean and proper because injured peoples and killed peoples prmary visti the hospital. We can use the latest echnology ot save the injured peoples life like robotic surgery etc. Provide Mobile ICU Services for Injured peoples to receove them as soon as possible. IoT services can make hospital better and provides availabilites of doctors during the emergency time
# ## **3. Infrastructure Impact:**
# Due to attacks on Public and Private places infracsturcture damange loss we observed and to revoce infrasturcture damange we can use 3D Printing technology which will develope and reconstruct the homes
# ## **4. Transportation Impact:**
# Public and Private Transportaion services we can track the balck ship on the perticular high density area of peoples by using high quality metal detectore , CCTV using IoT and Alarms whenever necessary.
# ## **5. Security Services Impact:**
# Our security gurad are well trained and available on each area like infrastruct , Transportatioin and Hospital services which is basic of any city.
# After that we need to arrange special team of police force and army officers to recovers from the terrorist activities

# %% [markdown]
# ## **Chart-8  Top 10 City wise ATTACKS, CASUALITY, KILLED and INJURED Peoples**

# %% [markdown]
# ### **Attack**

# %%
selected_data.columns

# %%
CWA=selected_data["city"].value_counts()[1:11]
CWA

# %%
CWA.plot(kind="bar",
        figsize=(20,15),
         color=['g'],
        fontsize=15)
plt.title("From 1970 to 2017 TOP 10 City Wise Total attacks",fontsize=15)
plt.xlabel("City Name",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# ## **Casualities Peoples**

# %%
CityWC=selected_data[["city","Casualty"]].groupby("city").sum().sort_values(by="Casualty",ascending=False).head(10)
CityWC

# %%
CityWC.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("From Year 1970 to 2017 TOP 10 City Wise Casuality",fontsize=15)
plt.xlabel("City Name",fontsize=15)
plt.ylabel("Number of Casuality",fontsize=15)
plt.show()

# %% [markdown]
# ## **killed Peoples**

# %%
CityWK=selected_data[["city","Total_Killed"]].groupby("city").sum().sort_values(by="Total_Killed",ascending=False).head(10)
CityWK

# %%
CityWK.plot(kind="bar",
        figsize=(20,15),
        color=['r'],
        fontsize=15)
plt.title("From Year 1970 to 2017 TOP 10 City wise Total Killed",fontsize=15)
plt.xlabel("City Name",fontsize=15)
plt.ylabel("Number of Killed Peoples ",fontsize=15)
plt.show()

# %% [markdown]
# ### **Injured Peoples**

# %%
CityWI=selected_data[["city","Total_Injured"]].groupby("city").sum().sort_values(by="Total_Injured",ascending=False).head(10)
CityWI

# %%
CityWI.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("From Year 1970 to 2017 TOP 10 City wise Total Injured",fontsize=15)
plt.xlabel("City Name",fontsize=15)
plt.ylabel("Number of Injured People",fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# Bar chart easily uderstand for single variable of data it is most preferable
# ##### 2. What is/are the insight(s) found from the chart?
# 1.   Aattacks
# * In the city **Baghdad** *maximum number* of t**errorist    Aattacks** are observed
# * In the city **Athens** *minmum number* of t**errorist    Aattacks** are observed
#
# 2.   Causalities Peoples
# * In the city **Baghdad** *maximum number* of **Causalities Peoples** are observed
# * In the city **Colombo**  minmum number* of **causalities Peoples** are observed
# 3. Killed People
# * In the city **Baghdad** *maximum number* of **peoples killed** due to terrorist    Aattacks are observed
# * In the city **Maiduguri** *minmum number* of **peoples killed** due to terrorist    Aattacks are observed
# 4. Injured Peoples
# * In the city **Baghdad** *maximum number* of **peoples Injured** due to terrorist    Aattacks are observed
# * In the city **Kirkuk** *minmum number* of **peoples Injured** due to terrorist    Aattacks are observed
#
# ##### 3. Will the gained insights help creating a positive business impact?
# ## **1. City Impact:**
# Monitor the population of city and important infrastructure of city where possibilities of Terrorist attacks are more and Implement latest technology like IoT Based CCTV Cameras , Secure Biomatirc and metal detectore are utilize for the entry and exit points of VIP and Important area of city like Government offers, Schools , Coleges and Various croudy areas
# ## **2. Hospital Impact:**
# Hostipal facility are clean and proper because injured peoples and killed peoples prmary visti the hospital. We can use the latest echnology ot save the injured peoples life like robotic surgery etc. Provide Mobile ICU Services for Injured peoples to receove them as soon as possible. IoT services can make hospital better and provides availabilites of doctors during the emergency time
# ## **3. Infrastructure Impact:**
# Due to attacks on Public and Private places infracsturcture damange loss we observed and to revoce infrasturcture damange we can use 3D Printing technology which will develope and reconstruct the homes
# ## **4. Transportation Impact:**
# Public and Private Transportaion services we can track the balck ship on the perticular high density area of peoples by using high quality metal detectore , CCTV using IoT and Alarms whenever necessary.
# ## **5. Security Services Impact:**
# Our security gurad are well trained and available on each area like infrastruct , Transportatioin and Hospital services which is basic of any city.
# After that we need to arrange special team of police force and army officers to recovers from the terrorist activities

# %% [markdown]
# ### **Chart-9  Top 10 Terrorist Group wise ATTACKS, CASUALITY, KILLED and INJURED Peoples**

# %% [markdown]
# ## **Attack**

# %%
selected_data.columns

# %%
TGA=selected_data["Perpetrator_Group_Name"].value_counts()[1:11]
TGA

# %%
TGA.plot(kind="bar",
        figsize=(20,15),
         color=['g'],
        fontsize=15)
plt.title("From Year 1970 to 2017 TOP 10 Terrorist Group wise Attacks",fontsize=15)
plt.xlabel("Terrorist Group Name",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# ## **Injured Peoples**

# %%
TGI=selected_data[["Perpetrator_Group_Name","Total_Injured"]].groupby("Perpetrator_Group_Name").sum().sort_values(by="Total_Injured",ascending=False)[1:11]
TGI

# %%
TGI.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("From Year 1970 to 2017 TOP 10 Terrorist Group wise Total Injured",fontsize=15)
plt.xlabel("Terrorist Group Name",fontsize=15)
plt.ylabel("Number of Injured Peoples",fontsize=15)
plt.show()

# %% [markdown]
# ## **Killed Peoples**

# %%
TGKilled=selected_data[["Perpetrator_Group_Name","Total_Killed"]].groupby("Perpetrator_Group_Name").sum().sort_values(by="Total_Killed",ascending=False)[1:11]
TGKilled

# %%
TGKilled.plot(kind="bar",
        figsize=(20,15),
        color=['r'],
        fontsize=15)
plt.title("From Year 1970 to 2017 TOP 10 Terrorist Group wise Total Killed",fontsize=15)
plt.xlabel("Terrorist Group Name",fontsize=15)
plt.ylabel("Number of Killed Peoples",fontsize=15)
plt.show()

# %% [markdown]
# ## **Casualty**

# %%
selected_data.columns

# %%
TGC=selected_data[["Perpetrator_Group_Name","Casualty"]].groupby("Perpetrator_Group_Name").sum().sort_values(by="Casualty",ascending=False)[1:11]
TGC

# %%
TGC.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("From Year 1970 to 2017 TOP 10 Terrorist Group wise Total Casualty",fontsize=15)
plt.xlabel("Terrorist Group Name",fontsize=15)
plt.ylabel("Number of Casualty",fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# Bar chart easily uderstand for single variable of data it is most preferable
# ##### 2. What is/are the insight(s) found from the chart?
# 1.   Aattacks
# * **Taliban** implement *maximum number* of t**errorist    Aattacks** are observed
# * **Kurdistan Workers' Party (PKK)** implement *minmum number* of t**errorist    Aattacks** are observed
#
# 2.   Causalities Peoples
# * **Islamic State of Iraq and the Levant (ISIL)** terriorst group *maximum number* of **Causalities Peoples** are observed
# * **Farabundo Marti National Liberation Front (FMLN)** terrorist group minmum number* of **causalities Peoples** are observed
# 3. Killed People
# *  **Islamic State of Iraq and the Levant (ISIL)** terrorist group *maximum number* of **peoples killed** due to terrorist    Aattacks are observed
# * **Revolutionary Armed Forces of Colombia (FARC)** terrorist group *minmum number* of **peoples killed** due to terrorist    Aattacks are observed
# 4. Injured Peoples
# * **Islamic State of Iraq and the Levant (ISIL)** terrorist group *maximum number* of **peoples Injured** due to terrorist    Aattacks are observed
# * **Kurdistan Workers' Party (PKK)** terrorist group *minmum number* of **peoples Injured** due to terrorist    Aattacks are observed
#
# ##### 3. Will the gained insights help creating a positive business impact?
# ## **1. City Impact:**
# Monitor the population of city and important infrastructure of city where possibilities of Terrorist attacks are more and Implement latest technology like IoT Based CCTV Cameras , Secure Biomatirc and metal detectore are utilize for the entry and exit points of VIP and Important area of city like Government offers, Schools , Coleges and Various croudy areas
# ## **2. Hospital Impact:**
# Hostipal facility are clean and proper because injured peoples and killed peoples prmary visti the hospital. We can use the latest echnology ot save the injured peoples life like robotic surgery etc. Provide Mobile ICU Services for Injured peoples to receove them as soon as possible. IoT services can make hospital better and provides availabilites of doctors during the emergency time
# ## **3. Infrastructure Impact:**
# Due to attacks on Public and Private places infracsturcture damange loss we observed and to revoce infrasturcture damange we can use 3D Printing technology which will develope and reconstruct the homes
# ## **4. Transportation Impact:**
# Public and Private Transportaion services we can track the balck ship on the perticular high density area of peoples by using high quality metal detectore , CCTV using IoT and Alarms whenever necessary.
# ## **5. Security Services Impact:**
# Our security gurad are well trained and available on each area like infrastruct , Transportatioin and Hospital services which is basic of any city.
# After that we need to arrange special team of police force and army officers to recovers from the terrorist activities

# %% [markdown]
# ## **Chart-10  Various Type of Attacks wise ATTACKS, CASUALITY, KILLED and INJURED Peoples**

# %% [markdown]
# ## **Attacks**

# %%
selected_data.columns

# %%
ATA=selected_data["Type_of_Attack"].value_counts()
ATA

# %%
ATA.plot(kind="bar",
        figsize=(20,15),
         color=['g'],
        fontsize=15)
plt.title("Type of Attack wise total attacks ",fontsize=15)
plt.xlabel("Attack Names",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# 1. Technology equipment for identification of explosion
# 2. Indian explosive we can track and maintain the database of our Weapons to avoid theft

# %% [markdown]
# ## **Casualty**

# %%
TKA=selected_data[["Type_of_Attack","Casualty"]].groupby("Type_of_Attack").sum().sort_values(by="Casualty",ascending=False)
TKA

# %%
TKA.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("Type of Attack wise total casualty ",fontsize=15)
plt.xlabel("Arrack Name",fontsize=15)
plt.ylabel("Number of Total casualty",fontsize=15)
plt.show()

# %% [markdown]
# ## **Killed**

# %%
TAkilled=selected_data[["Type_of_Attack","Total_Killed"]].groupby("Type_of_Attack").sum().sort_values(by="Total_Killed",ascending=False)
TAkilled

# %%
TAkilled.plot(kind="bar",
        figsize=(20,15),
        color=['r'],
        fontsize=15)
plt.title("Type of Attack wise total Killed ",fontsize=15)
plt.xlabel("Type of Attack ",fontsize=15)
plt.ylabel("Number of Killed Peoples",fontsize=15)
plt.show()

# %% [markdown]
# ##**Injured Peoples**

# %%
TAInjured=selected_data[["Type_of_Attack","Total_Injured"]].groupby("Type_of_Attack").sum().sort_values(by="Total_Injured",ascending=False)
TAInjured

# %%
TAInjured.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("Type of Attack wise total Ijured Peoples ",fontsize=15)
plt.xlabel("Type of attack Name",fontsize=15)
plt.ylabel("Number of Injured Peoples",fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# Bar chart easily uderstand for single variable of data it is most preferable
# ##### 2. What is/are the insight(s) found from the chart?
# 1.   Aattacks
# * **Bombing/Explosion** used for  *maximum number* of t**errorist    Aattacks** are observed
# * **Hijacking** used for  *minmum number* of t**errorist    Aattacks** are observed
#
# 2.   Causalities Peoples
# * **Bombing/Explosion** attack type  *maximum number* of **Causalities Peoples** due to Bombing/Explosion attack are observed
# * **Facility/Infrastructure Attack** attack type minmum number* of **causalities Peoples** are observed due to Facility/Infrastructure Attack
# 3. Killed People
# *  **Armed Assault** attack type  *maximum number* of **peoples killed** due to terrorist Armed Assault type attack are observed
# * **Unarmed Assault** attack type *minmum number* of **peoples killed** due to terrorist  Unarmed Assault type aattacks are observed
# 4. Injured Peoples
# * **Bombing/Explosion** attack type  *maximum number* of **peoples Injured** due to Bombing Aattacks are observed
# * **Facility/Infrastructure Attack**  attack type *minmum number* of **peoples Injured** due to Facility/Infrastructure Attack Aattacks are observed
#
# ##### 3. Will the gained insights help creating a positive business impact?
# ## **1. City Impact:**
# Monitor the population of city and important infrastructure of city where possibilities of Terrorist attacks are more and Implement latest technology like IoT Based CCTV Cameras , Secure Biomatirc and metal detectore are utilize for the entry and exit points of VIP and Important area of city like Government offers, Schools , Coleges and Various croudy areas
# ## **2. Hospital Impact:**
# Hostipal facility are clean and proper because injured peoples and killed peoples prmary visti the hospital. We can use the latest echnology ot save the injured peoples life like robotic surgery etc. Provide Mobile ICU Services for Injured peoples to receove them as soon as possible. IoT services can make hospital better and provides availabilites of doctors during the emergency time
# ## **3. Infrastructure Impact:**
# Due to attacks on Public and Private places infracsturcture damange loss we observed and to revoce infrasturcture damange we can use 3D Printing technology which will develope and reconstruct the homes
# ## **4. Transportation Impact:**
# Public and Private Transportaion services we can track the balck ship on the perticular high density area of peoples by using high quality metal detectore , CCTV using IoT and Alarms whenever necessary.
# ## **5. Security Services Impact:**
# Our security gurad are well trained and available on each area like infrastruct , Transportatioin and Hospital services which is basic of any city.
# After that we need to arrange special team of police force and army officers to recovers from the terrorist activities

# %% [markdown]
# ## **Chart-11 Target Location wise ATTACKS, CASUALITY, KILLED and INJURED Peoples**

# %% [markdown]
# ## **Attacks**

# %%
TTAttack=selected_data["Target_Location"].value_counts()
TTAttack

# %%
TTAttack.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("Type of Attack wise total Attack ",fontsize=15)
plt.xlabel("Target Location Name ",fontsize=15)
plt.ylabel("Number of  Attack",fontsize=15)
plt.show()

# %% [markdown]
# ## **Killed**

# %%
TTKilled=selected_data[["Target_Location","Total_Killed"]].groupby("Target_Location").sum().sort_values(by="Target_Location",ascending=False)
TTKilled

# %%
TTKilled.plot(kind="bar",
        figsize=(20,15),
        color=['r'],
        fontsize=15)
plt.title("Type of Attack wise total killed ",fontsize=15)
plt.xlabel("Target Location Name ",fontsize=15)
plt.ylabel("Total Killed",fontsize=15)
plt.show()

# %% [markdown]
# ## **Injured**

# %%
TTInjured=selected_data[["Target_Location","Total_Injured"]].groupby("Target_Location").sum().sort_values(by="Target_Location",ascending=False)
TTInjured

# %%
TTInjured.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("Type of Attack wise total killed ",fontsize=15)
plt.xlabel("Type of attack wise total killed",fontsize=15)
plt.ylabel("Number of Types Total Killed",fontsize=15)
plt.show()

# %% [markdown]
# ## **Casualities**

# %%
selected_data.columns

# %%
TTCasulity=selected_data[["Target_Location","Casualty"]].groupby("Target_Location").sum().sort_values(by="Target_Location",ascending=False)
TTCasulity

# %%
selected_data.columns

# %%
TTCasulity.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("Type of Attack wise total Casualty ",fontsize=15)
plt.xlabel("Type of attack wise total v",fontsize=15)
plt.ylabel("Number of Types Total Casualty",fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# Bar chart easily uderstand for single variable of data it is most preferable
# ##### 2. What is/are the insight(s) found from the chart?
# 1.   Aattacks
# * On **Private Citizens & Property** their are *maximum number* of t**errorist    Aattacks** are observed
#
#
# 2.   Causalities Peoples
# * On **Private Citizens & Property** their are *maximum number* of **Causalities Peoples** are observed
#
# 3. Killed People
# * On **Private Citizens & Property** their are *maximum number* of **Killed People** are observed
# 4. Injured Peoples
# * On **Private Citizens & Property** their are *maximum number* of **Injured Peoples** are observed
#
# ##### 3. Will the gained insights help creating a positive business impact?
# ## **1. City Impact:**
# Monitor the population of city and important infrastructure of city where possibilities of Terrorist attacks are more and Implement latest technology like IoT Based CCTV Cameras , Secure Biomatirc and metal detectore are utilize for the entry and exit points of VIP and Important area of city like Government offers, Schools , Coleges and Various croudy areas
# ## **2. Hospital Impact:**
# Hostipal facility are clean and proper because injured peoples and killed peoples prmary visti the hospital. We can use the latest echnology ot save the injured peoples life like robotic surgery etc. Provide Mobile ICU Services for Injured peoples to receove them as soon as possible. IoT services can make hospital better and provides availabilites of doctors during the emergency time
# ## **3. Infrastructure Impact:**
# Due to attacks on Public and Private places infracsturcture damange loss we observed and to revoce infrasturcture damange we can use 3D Printing technology which will develope and reconstruct the homes
# ## **4. Transportation Impact:**
# Public and Private Transportaion services we can track the balck ship on the perticular high density area of peoples by using high quality metal detectore , CCTV using IoT and Alarms whenever necessary.
# ## **5. Security Services Impact:**
# Our security gurad are well trained and available on each area like infrastruct , Transportatioin and Hospital services which is basic of any city.
# After that we need to arrange special team of police force and army officers to recovers from the terrorist activities

# %% [markdown]
# ## **Chart-12 Country and Terrorist Group wise ATTACKS, CASUALITY, KILLED and INJURED Peoples**

# %% [markdown]
# ## Attack

# %%
selected_data.columns

# %%
TGNCountry=selected_data[["Perpetrator_Group_Name","Country_name"]].value_counts().drop("Unknown").head(10)
TGNCountry

# %%
TGNCountry.plot(kind="bar",
        figsize=(20,15),
        color=['g'],
        fontsize=15)

plt.title("Country and Terrorist group wise attack ",fontsize=15)
plt.xlabel("Name of Terrorist Group",fontsize=15)
plt.ylabel("Number of Attack",fontsize=15)
plt.legend(labels=["Country_name","Perpetrator_Group_Name"])
plt.bar(range(len(TGNCountry)), TGNCountry)
plt.bar(range(len(TGNCountry)), TGNCountry, bottom=TGNCountry)
plt.show()

# %% [markdown]
# ## **Killed**

# %%
TGNCKilled=selected_data[["Perpetrator_Group_Name","Country_name","Total_Killed"]].groupby(["Perpetrator_Group_Name","Country_name"],axis=0).sum().sort_values(by="Total_Killed",ascending=False).head(10)
TGNCKilled

# %%
TGNCKilled1=selected_data[["Perpetrator_Group_Name","Country_name","Total_Killed"]].value_counts().drop("Unknown").head(10)
TGNCKilled1

# %%
TGNCKilled1.plot(kind="bar",
        figsize=(20,15),
        color=['b','r'],
        fontsize=15)

plt.title("Country and Terrorist group wise attack ",fontsize=15)
plt.xlabel("Name of Terrorist Group",fontsize=15)
plt.ylabel("Number of Attack",fontsize=15)
plt.legend(labels=["Country_name","Perpetrator_Group_Name"])
plt.bar(range(len(TGNCKilled1)),TGNCKilled1)
plt.bar(range(len(TGNCKilled1)), TGNCKilled1, bottom=TGNCKilled1)
plt.show()

# %% [markdown]
# ## **Injured Peoples**

# %%
CWTGInjured=selected_data[["Perpetrator_Group_Name","Country_name","Total_Injured"]].groupby(["Perpetrator_Group_Name","Country_name"],axis=0).sum().sort_values(by="Total_Injured",ascending=False).head(10)
CWTGInjured

# %%
CWTGInjured1=selected_data[["Perpetrator_Group_Name","Country_name","Total_Killed"]].value_counts().drop("Unknown").head(10)
CWTGInjured1

# %%
CWTGInjured1.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("Country and Terrorist group wise top 10 Injured",fontsize=15)
plt.xlabel("Name of Terrorist Group",fontsize=15)
plt.ylabel("Number of Injured Peoples",fontsize=15)
plt.bar(range(len(CWTGInjured1)),CWTGInjured1)
plt.bar(range(len(CWTGInjured1)), CWTGInjured1, bottom=CWTGInjured1)
plt.show()

# %% [markdown]
# ## **Casualty**

# %%
selected_data.columns

# %%
CWTGCasualty=selected_data[["Perpetrator_Group_Name","Country_name","Casualty"]].groupby(["Perpetrator_Group_Name","Country_name"],axis=0).sum().sort_values(by="Casualty",ascending=False).head(10)
CWTGCasualty

# %%
CWTGCasualty1=selected_data[["Perpetrator_Group_Name","Country_name","Total_Killed"]].value_counts().drop("Unknown").head(10)
CWTGCasualty1

# %%
CWTGInjured1.plot(kind="bar",
        figsize=(20,15),
        fontsize=15)
plt.title("Country and Terrorist group wise top 10 Injured",fontsize=15)
plt.xlabel("Name of Terrorist Group",fontsize=15)
plt.ylabel("Number of Injured Peoples",fontsize=15)
plt.bar(range(len(CWTGInjured1)),CWTGInjured1)
plt.bar(range(len(CWTGInjured1)), CWTGInjured1, bottom=CWTGInjured1)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# Bar chart easily uderstand for single variable of data it is most preferable
# ##### 2. What is/are the insight(s) found from the chart?
# 1.   Aattacks
# * Terrorist group is **Taliban **and affected country is **Afghanistan** where **maximum number** of attacks are observed
# * Terrorist group is **Boko Haram** and affected country is **Nigeria**
# where **minimum number** of attacks are observed
#
#
# 2.   Causalities Peoples
# * Terrorist group is **Shining Path (SL)**and affected country is **Peru** where **maximum number** of attacks are observed
# * Terrorist group is **Al-Shabaab** and affected country is **Somalia**
# where **minimum number** of attacks are observed
# 3. Killed People
# * Terrorist group is **Shining Path (SL)**and affected country is **Peru** where **maximum number** of attacks are observed
# * Terrorist group is **Al-Shabaab** and affected country is **Somalia**
# where **minimum number** of attacks are observed
# 4. Injured Peoples
# * Terrorist group is **Shining Path (SL)**and affected country is **Peru** where **maximum number** of attacks are observed
# * Terrorist group is **Al-Shabaab** and affected country is **Somalia**
# where **minimum number** of attacks are observed
#
# ##### 3. Will the gained insights help creating a positive business impact?
# ## **1. City Impact:**
# Monitor the population of city and important infrastructure of city where possibilities of Terrorist attacks are more and Implement latest technology like IoT Based CCTV Cameras , Secure Biomatirc and metal detectore are utilize for the entry and exit points of VIP and Important area of city like Government offers, Schools , Coleges and Various croudy areas
# ## **2. Hospital Impact:**
# Hostipal facility are clean and proper because injured peoples and killed peoples prmary visti the hospital. We can use the latest echnology ot save the injured peoples life like robotic surgery etc. Provide Mobile ICU Services for Injured peoples to receove them as soon as possible. IoT services can make hospital better and provides availabilites of doctors during the emergency time
# ## **3. Infrastructure Impact:**
# Due to attacks on Public and Private places infracsturcture damange loss we observed and to revoce infrasturcture damange we can use 3D Printing technology which will develope and reconstruct the homes
# ## **4. Transportation Impact:**
# Public and Private Transportaion services we can track the balck ship on the perticular high density area of peoples by using high quality metal detectore , CCTV using IoT and Alarms whenever necessary.
# ## **5. Security Services Impact:**
# Our security gurad are well trained and available on each area like infrastruct , Transportatioin and Hospital services which is basic of any city.
# After that we need to arrange special team of police force and army officers to recovers from the terrorist activities

# %% [markdown]
# ## **Chart-13 Country and Terrorist Group wise ATTACKS, CASUALITY, KILLED and INJURED Peoples**

# %% [markdown]
# ## **Attack**

# %% [markdown]
# #### Total Casalties because of Terrorist attack

# %%
selected_data.columns

# %%
Total_Casualty=selected_data.loc[:,"Casualty"].sum()
print("From1970 to 2017 Total number of Casualties across the world",Total_Casualty)

# %% [markdown]
# ### Total Killed During year 1970 to 2017

# %%
Total_Killed=selected_data.loc[:,"Total_Killed"].sum()
print("From1970 to 2017 Total number of Killed across the world",Total_Killed)

# %% [markdown]
# ### Total Injured During year 1970 to 2017

# %%
Total_Injured=selected_data.loc[:,"Total_Injured"].sum()
print("From1970 to 2017 Total number of Injured across the world",Total_Injured)

# %% [markdown]
# ## **Chart - 13 - Correlation Heatmap**

# %%
# Correlation Heatmap visualization code
corr = selected_data.corr()
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())

# %% [markdown]
# ## **Chart - 14 - Pair Plot**

# %%
sns.pairplot(selected_data)

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# 1. We can use** High Tech equipment** to overcome pre and post terrorist attacks. Defense manufacturing , Electronics and telecommunications equipment , Pharmaceutical industry , Medical device manufacturing  these are most common fields where we can improve our technology for better security and better services.
# 2. When we are using **High Tech Equipment** that time we **need trained and skilled manpower**. If manpower is eligible for role then we can provide them with **training in assoication with the perticular industry** in this way we **develope and Protect our technology** with our own hands.
# 3. Some Terrorist **motive is for money** they attack. Such t**errorist we can convert into the normal peoples** because onces they **satisfied with their needs**.and we can fullfill their needs using **upskilling and latest technology**. So terrorist group and terrorist mind peoples ration will decrease.
# 4. Security is most important factor in terrorist attacks so our **normal security guard we can convert into spy agent with help of High tech Technology**
# 5. Infrastructure : Destroy infrasturacture using 3d Printer we can develop new latest infrasturacture and overcome the situtaion.
# 6. Health : **Blood avalibility and specility of doctors** are most important paramaeter for any hospital after attacks need of these resources are increases so we can monitor and arrange the services as per the need

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1.	Year 1970 to 2017 Total number of **Casualties** across the world 935737.0
# 2.	Year 1970 to 2017 Total number of **Killed** across the world 411868.0
# 3.	Year 1970 to 2017 Total number of **Injured** across the world 523869.0
# 4.	**Taliban and Shining Path (SL)** these group attacks mostly
# 5.	**Private Citizens & Property , Police , Transportation , Military , Government and Business park** are mostly famous target of terrorist peoples
# 6.	**Bombing/Explosion, Armed Assault** these are favorite attacking types of terrorist
# 7.	96.5% terrorist **attacks is for money** so using High tech technology we can minimize this percentage
